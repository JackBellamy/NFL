# %% [markdown]
# **Importing the data**

# %%
# imports
from IPython.display import clear_output
from PIL import Image
import os
import json
# clear
clear_output(wait=True)
# installing kaggle
# !pip install -q kaggle
# user and key info
info = {"username":"jackbellamy","key":"3442898ba5e904ac3a48eb5b59398805"}
# opening file
json_object = json.dumps(info, indent=4)
with open("kaggle.json", "w") as outfile:
    outfile.write(json_object)
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# copying data to content file of kaggle which can be found on the left hand side of the screen
if not (os.path.exists("/content/nfl-big-data-bowl-2022")):
  # !kaggle competitions download -c nfl-big-data-bowl-2022
  # !mkdir nfl-big-data-bowl-2022
  # !unzip nfl-big-data-bowl-2022.zip -d nfl-big-data-bowl-2022
# Out:
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# mkdir: /Users/alexbott/.kaggle: File exists
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     161                 # know whether we've finished (if we matched EOF) or not
# --> 162                 res_idx = child.expect_list(patterns, self.read_timeout)
#     163                 print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371         else:
# --> 372             return exp.expect_loop(timeout)
#     373
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pexpect/expect.py in expect_loop(self, timeout)
#     168                 # Still have time left, so read more data
# --> 169                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170                 if self.spawn.delayafterread is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pexpect/pty_spawn.py in read_nonblocking(self, size, timeout)
#     499         # (possibly timeout=None), we call select() with a timeout.
# --> 500         if (timeout != 0) and select(timeout):
#     501             return super(spawn, self).read_nonblocking(size)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pexpect/pty_spawn.py in select(timeout)
#     449             def select(timeout):
# --> 450                 return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#     451
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pexpect/utils.py in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142         try:
# --> 143             return select.select(iwtd, owtd, ewtd, timeout)
#     144         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-61-a75789e179eb> in <module>
#      19 # copying data to content file of kaggle which can be found on the left hand side of the screen
#      20 if not (os.path.exists("/content/nfl-big-data-bowl-2022")):
# ---> 21   get_ipython().system('kaggle competitions download -c nfl-big-data-bowl-2022')
#      22   get_ipython().system('mkdir nfl-big-data-bowl-2022')
#      23   get_ipython().system('unzip nfl-big-data-bowl-2022.zip -d nfl-big-data-bowl-2022')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     633                 self.user_ns['_exit_code'] = system(cmd)
#     634         else:
# --> 635             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     636
#     637     # Ensure new system_piped implementation is used
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     171             # (the character is known as ETX for 'End of Text', see
#     172             # curses.ascii.ETX).
# --> 173             child.sendline(chr(3))
#     174             # Read and print any more output the program might produce on its
#     175             # way out.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pexpect/pty_spawn.py in sendline(self, s)
#     576         '''
#     577         s = self._coerce_send_string(s)
# --> 578         return self.send(s + self.linesep)
#     579
#     580     def _log_control(self, s):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pexpect/pty_spawn.py in send(self, s)
#     567
#     568         b = self._encoder.encode(s, final=False)
# --> 569         return os.write(self.child_fd, b)
#     570
#     571     def sendline(self, s=''):
#
# OSError: [Errno 5] Input/output error

# %% [markdown]
# **Calling data files to variables**

# %%
import pandas as pd
# reading the data to variables
scouting = pd.read_csv("nfl-big-data-bowl-2022/PFFScoutingData.csv")
games = pd.read_csv("nfl-big-data-bowl-2022/games.csv")
players = pd.read_csv("nfl-big-data-bowl-2022/players.csv")
plays = pd.read_csv("nfl-big-data-bowl-2022/plays.csv")
tracking2018 = pd.read_csv("nfl-big-data-bowl-2022/tracking2018.csv")
tracking2019 = pd.read_csv("nfl-big-data-bowl-2022/tracking2019.csv")
tracking2020 = pd.read_csv("nfl-big-data-bowl-2022/tracking2020.csv")

# %% [markdown]
# Datasizes

# %%
data = [scouting,games,players,plays,tracking2018,tracking2019,tracking2020]
# loop
for name in data:
  print(name.shape)
# Out:
# (19979, 20)
# (764, 7)
# (2732, 7)
# (19979, 25)
# (12777351, 18)
# (12170933, 18)
# (11821701, 18)

# %% [markdown]
# Downcast compressing:

# %%
def downcast(df, verbose=True):
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        dtype_name = df[col].dtype.name
        if dtype_name == 'object':
            pass
        elif dtype_name == 'bool':
            df[col] = df[col].astype('int8')
        elif dtype_name.startswith('int') or (df[col].round() == df[col]).all():
            df[col] = pd.to_numeric(df[col], downcast='integer')
        else:
            df[col] = pd.to_numeric(df[col], downcast='float')
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose:
        print('{:.1f}% Compressed'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
games = downcast(games)
scouting = downcast(scouting)
players = downcast(players)
plays = downcast(plays)
tracking2018 = downcast(tracking2018)
tracking2019 = downcast(tracking2019)
tracking2020 = downcast(tracking2020)
# Out:
# 30.3% Compressed
# 13.7% Compressed
# 17.8% Compressed
# 43.0% Compressed
# 36.1% Compressed
# 36.1% Compressed
# 36.1% Compressed

# %% [markdown]
# **Data sizes**

# %%
data = [scouting,games,players,plays,tracking2018,tracking2019,tracking2020]
# loop
for name in data:
  print(name.shape)
# Out:
# (19979, 20)
# (764, 7)
# (2732, 7)
# (19979, 25)
# (12777351, 18)
# (12170933, 18)
# (11821701, 18)

# %% [markdown]
# BASIC DQ check

# %%
import EDA

EDA.dq_check(games,verbose=1)
# Out:
# /Users/alexbott/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#                 Data_Type  Populated_Count  Null_Count  %_Populated  Blank  \
# gameId              int32              764           0      100.000      0
# season              int16              764           0      100.000      0
# week                 int8              764           0      100.000      0
# gameDate           object              764           0      100.000      0
# gameTimeEastern    object              764           0      100.000      0
# homeTeamAbbr       object              764           0      100.000      0
# visitorTeamAbbr    object              764           0      100.000      0
# len                 int64              764           0      100.000      0
#
#                  %_Populated_Non_Blank  SingleSpace  %_Populated_Non_Space  \
# gameId                         100.000            0                100.000
# season                         100.000            0                100.000
# week                           100.000            0                100.000
# gameDate                       100.000            0                100.000
# gameTimeEastern                100.000            0                100.000
# homeTeamAbbr                   100.000            0                100.000
# visitorTeamAbbr                100.000            0                100.000
# len                            100.000            0                100.000
#
#                  Unique_Values              Mean  ...     Minimum_Value  \
# gameId                     764 2,019,130,544.923  ... 2,018,090,600.000
# season                       3         2,019.004  ...         2,018.000
# week                        17             9.076  ...             1.000
# gameDate                   151               nan  ...        01/03/2021
# gameTimeEastern             16               nan  ...          09:30:00
# homeTeamAbbr                33               nan  ...               ARI
# visitorTeamAbbr             33               nan  ...               ARI
# len                          2             2.772  ...             2.000
#
#                        Quartile 1            Median        Quartile 3  \
# gameId          2,018,120,900.750 2,019,110,307.500 2,020,101,100.250
# season                  2,018.000         2,019.000         2,020.000
# week                        5.000             9.000            14.000
# gameDate                      nan               nan               nan
# gameTimeEastern               nan               nan               nan
# homeTeamAbbr                  nan               nan               nan
# visitorTeamAbbr               nan               nan               nan
# len                         3.000             3.000             3.000
#
#                         Max_Value        mode Coefficeint Of Variance  \
# gameId          2,021,010,315.000  2020102200                   0.000
# season                  2,020.000        2020                   0.000
# week                       17.000          17                   0.551
# gameDate               12/30/2018  12/30/2018                     nan
# gameTimeEastern          22:20:00    13:00:00                     nan
# homeTeamAbbr                  WAS         CLE                     nan
# visitorTeamAbbr               WAS         CLE                     nan
# len                         3.000           3                   0.151
#
#                  Total_Outliers  Min Text Length  Max Text Length
# gameId                    0.000              nan              nan
# season                    0.000              nan              nan
# week                      0.000              nan              nan
# gameDate                    nan           10.000           10.000
# gameTimeEastern             nan            8.000            8.000
# homeTeamAbbr                nan            2.000            3.000
# visitorTeamAbbr             nan            2.000            3.000
# len                     174.000              nan              nan
#
# [8 rows x 21 columns]

# %%
EDA.dq_check(scouting,verbose=1)
# Out:
# /Users/alexbott/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#                         Data_Type  Populated_Count  Null_Count  %_Populated  \
# gameId                      int32            19979           0      100.000
# playId                      int16            19979           0      100.000
# snapDetail                 object             5919       14060       29.626
# snapTime                  float32             5918       14061       29.621
# operationTime             float32             5918       14061       29.621
# hangTime                  float32            13098        6881       65.559
# kickType                   object            13723        6256       68.687
# kickDirectionIntended      object            13701        6278       68.577
# kickDirectionActual        object            13701        6278       68.577
# returnDirectionIntended    object             4754       15225       23.795
# returnDirectionActual      object             4756       15223       23.805
# missedTackler              object             1348       18631        6.747
# assistTackler              object             1034       18945        5.175
# tackler                    object             4759       15220       23.820
# kickoffReturnFormation     object             7843       12136       39.256
# gunners                    object             5901       14078       29.536
# puntRushers                object             3010       16969       15.066
# specialTeamsSafeties       object            15937        4042       79.769
# vises                      object             5878       14101       29.421
# kickContactType            object             5879       14100       29.426
#
#                          Blank  %_Populated_Non_Blank  SingleSpace  \
# gameId                       0                100.000            0
# playId                       0                100.000            0
# snapDetail                   0                100.000            0
# snapTime                     0                100.000            0
# operationTime                0                100.000            0
# hangTime                     0                100.000            0
# kickType                     0                100.000            0
# kickDirectionIntended        0                100.000            0
# kickDirectionActual          0                100.000            0
# returnDirectionIntended      0                100.000            0
# returnDirectionActual        0                100.000            0
# missedTackler                0                100.000            0
# assistTackler                0                100.000            0
# tackler                      0                100.000            0
# kickoffReturnFormation       0                100.000            0
# gunners                      0                100.000            0
# puntRushers                  0                100.000            0
# specialTeamsSafeties         0                100.000            0
# vises                        0                100.000            0
# kickContactType              0                100.000            0
#
#                          %_Populated_Non_Space  Unique_Values  \
# gameId                                 100.000            764
# playId                                 100.000           4435
# snapDetail                             100.000              5
# snapTime                               100.000             58
# operationTime                          100.000             97
# hangTime                               100.000            296
# kickType                               100.000             11
# kickDirectionIntended                  100.000              3
# kickDirectionActual                    100.000              3
# returnDirectionIntended                100.000              3
# returnDirectionActual                  100.000              3
# missedTackler                          100.000            860
# assistTackler                          100.000            576
# tackler                                100.000           1081
# kickoffReturnFormation                 100.000             16
# gunners                                100.000            926
# puntRushers                            100.000           2089
# specialTeamsSafeties                   100.000           3107
# vises                                  100.000           1779
# kickContactType                        100.000             14
#
#                                      Mean  ...           Minimum_Value  \
# gameId                  2,019,113,760.033  ...       2,018,090,600.000
# playId                          2,037.558  ...                  35.000
# snapDetail                            nan  ...                       <
# snapTime                            0.861  ...                   0.100
# operationTime                       2.131  ...                   1.380
# hangTime                            4.146  ...                   1.220
# kickType                              nan  ...                       A
# kickDirectionIntended                 nan  ...                       C
# kickDirectionActual                   nan  ...                       C
# returnDirectionIntended               nan  ...                       C
# returnDirectionActual                 nan  ...                       C
# missedTackler                         nan  ...                  ARI 16
# assistTackler                         nan  ...                  ARI 16
# tackler                               nan  ...                  ARI 02
# kickoffReturnFormation                nan  ...                  10-0-0
# gunners                               nan  ...          ARI 16; ARI 17
# puntRushers                           nan  ...                  ARI 16
# specialTeamsSafeties                  nan  ...          ARI 12; ARI 25
# vises                                 nan  ...  ARI 16; ARI 33; ARI 27
# kickContactType                       nan  ...                      BB
#
#                                Quartile 1            Median        Quartile 3  \
# gameId                  2,018,120,208.000 2,019,110,303.000 2,020,100,500.000
# playId                            985.000         2,033.000         3,027.000
# snapDetail                            nan               nan               nan
# snapTime                            0.830             0.860             0.900
# operationTime                       2.070             2.130             2.200
# hangTime                            3.920             4.120             4.380
# kickType                              nan               nan               nan
# kickDirectionIntended                 nan               nan               nan
# kickDirectionActual                   nan               nan               nan
# returnDirectionIntended               nan               nan               nan
# returnDirectionActual                 nan               nan               nan
# missedTackler                         nan               nan               nan
# assistTackler                         nan               nan               nan
# tackler                               nan               nan               nan
# kickoffReturnFormation                nan               nan               nan
# gunners                               nan               nan               nan
# puntRushers                           nan               nan               nan
# specialTeamsSafeties                  nan               nan               nan
# vises                                 nan               nan               nan
# kickContactType                       nan               nan               nan
#
#                                       Max_Value            mode  \
# gameId                        2,021,010,315.000      2018111900
# playId                                5,729.000              36
# snapDetail                                   OK              OK
# snapTime                                  1.190           0.850
# operationTime                             4.920           2.160
# hangTime                                  5.690           4.110
# kickType                                      S               D
# kickDirectionIntended                         R               C
# kickDirectionActual                           R               C
# returnDirectionIntended                       R               C
# returnDirectionActual                         R               C
# missedTackler                            WAS 88          BAL 10
# assistTackler                            WAS 83          LAC 48
# tackler                                  WAS 96          ARI 47
# kickoffReturnFormation                    9-1-0           8-0-2
# gunners                          WAS 89; WAS 83  SEA 28; SEA 23
# puntRushers                              WAS 99          PIT 45
# specialTeamsSafeties                     WAS 56  HOU 33; HOU 41
# vises                    WAS 48; WAS 41; WAS 38    LA 31; LA 25
# kickContactType                             OOB              CC
#
#                         Coefficeint Of Variance  Total_Outliers  \
# gameId                                    0.000           0.000
# playId                                    0.603           0.000
# snapDetail                                  nan             nan
# snapTime                                  0.073           0.000
# operationTime                             0.053           0.000
# hangTime                                  0.096           0.000
# kickType                                    nan             nan
# kickDirectionIntended                       nan             nan
# kickDirectionActual                         nan             nan
# returnDirectionIntended                     nan             nan
# returnDirectionActual                       nan             nan
# missedTackler                               nan             nan
# assistTackler                               nan             nan
# tackler                                     nan             nan
# kickoffReturnFormation                      nan             nan
# gunners                                     nan             nan
# puntRushers                                 nan             nan
# specialTeamsSafeties                        nan             nan
# vises                                       nan             nan
# kickContactType                             nan             nan
#
#                          Min Text Length  Max Text Length
# gameId                               nan              nan
# playId                               nan              nan
# snapDetail                           nan              nan
# snapTime                             nan              nan
# operationTime                        nan              nan
# hangTime                             nan              nan
# kickType                           1.000            1.000
# kickDirectionIntended              1.000            1.000
# kickDirectionActual                1.000            1.000
# returnDirectionIntended              nan              nan
# returnDirectionActual                nan              nan
# missedTackler                        nan              nan
# assistTackler                        nan              nan
# tackler                              nan              nan
# kickoffReturnFormation             5.000            6.000
# gunners                              nan              nan
# puntRushers                          nan              nan
# specialTeamsSafeties               5.000           46.000
# vises                                nan              nan
# kickContactType                      nan              nan
#
# [20 rows x 21 columns]

# %%
scouting.head()
# Out:
#        gameId  playId snapDetail  snapTime  operationTime  hangTime kickType  \
# 0  2018090600      37        NaN       nan            nan     3.850        D
# 1  2018090600     366         OK     0.840          2.120     4.460        N
# 2  2018090600     658        NaN       nan            nan       nan      NaN
# 3  2018090600     677        NaN       nan            nan     4.060        D
# 4  2018090600     872         OK     0.840          2.000     4.350        N
#
#   kickDirectionIntended kickDirectionActual returnDirectionIntended  ...  \
# 0                     R                   R                     NaN  ...
# 1                     C                   C                       C  ...
# 2                   NaN                 NaN                     NaN  ...
# 3                     R                   R                       C  ...
# 4                     C                   L                     NaN  ...
#
#   missedTackler assistTackler tackler kickoffReturnFormation         gunners  \
# 0           NaN           NaN     NaN                  8-0-2             NaN
# 1        PHI 57           NaN  PHI 54                    NaN  PHI 18; PHI 29
# 2           NaN           NaN     NaN                    NaN             NaN
# 3        ATL 83        ATL 22  ATL 27                  8-0-2             NaN
# 4           NaN           NaN     NaN                    NaN  PHI 18; PHI 29
#
#   puntRushers specialTeamsSafeties                           vises  \
# 0         NaN       PHI 23; PHI 27                             NaN
# 1         NaN                  NaN  ATL 83; ATL 27; ATL 34; ATL 21
# 2         NaN               PHI 58                             NaN
# 3         NaN       ATL 17; ATL 22                             NaN
# 4      ATL 85               ATL 37          ATL 83; ATL 34; ATL 21
#
#   kickContactType   len
# 0             NaN   nan
# 1              CC 2.000
# 2             NaN   nan
# 3             NaN   nan
# 4              BF 2.000
#
# [5 rows x 21 columns]

# %%
EDA.dq_check(plays,verbose=1)
# Out:
# /Users/alexbott/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#                        Data_Type  Populated_Count  Null_Count  %_Populated  \
# gameId                     int32            19979           0      100.000
# playId                     int16            19979           0      100.000
# playDescription           object            19979           0      100.000
# quarter                     int8            19979           0      100.000
# down                        int8            19979           0      100.000
# yardsToGo                   int8            19979           0      100.000
# possessionTeam            object            19979           0      100.000
# specialTeamsPlayType      object            19979           0      100.000
# specialTeamsResult        object            19979           0      100.000
# kickerId                 float32            19878         101       99.494
# returnerId                object             6938       13041       34.726
# kickBlockerId            float32              100       19879        0.501
# yardlineSide              object            19813         166       99.169
# yardlineNumber              int8            19979           0      100.000
# gameClock                 object            19979           0      100.000
# penaltyCodes              object             1102       18877        5.516
# penaltyJerseyNumbers      object             1102       18877        5.516
# penaltyYards             float32             1102       18877        5.516
# preSnapHomeScore            int8            19979           0      100.000
# preSnapVisitorScore         int8            19979           0      100.000
# passResult                object               45       19934        0.225
# kickLength               float32            16327        3652       81.721
# kickReturnYardage        float32             5324       14655       26.648
# playResult                  int8            19979           0      100.000
# absoluteYardlineNumber      int8            19979           0      100.000
#
#                         Blank  %_Populated_Non_Blank  SingleSpace  \
# gameId                      0                100.000            0
# playId                      0                100.000            0
# playDescription             0                100.000            0
# quarter                     0                100.000            0
# down                        0                100.000            0
# yardsToGo                   0                100.000            0
# possessionTeam              0                100.000            0
# specialTeamsPlayType        0                100.000            0
# specialTeamsResult          0                100.000            0
# kickerId                    0                100.000            0
# returnerId                  0                100.000            0
# kickBlockerId               0                100.000            0
# yardlineSide                0                100.000            0
# yardlineNumber              0                100.000            0
# gameClock                   0                100.000            0
# penaltyCodes                0                100.000            0
# penaltyJerseyNumbers        0                100.000            0
# penaltyYards                0                100.000            0
# preSnapHomeScore            0                100.000            0
# preSnapVisitorScore         0                100.000            0
# passResult                  0                100.000            0
# kickLength                  0                100.000            0
# kickReturnYardage           0                100.000            0
# playResult                  0                100.000            0
# absoluteYardlineNumber      0                100.000            0
#
#                         %_Populated_Non_Space  Unique_Values  \
# gameId                                100.000            764
# playId                                100.000           4435
# playDescription                       100.000          12355
# quarter                               100.000              5
# down                                  100.000              5
# yardsToGo                             100.000             38
# possessionTeam                        100.000             33
# specialTeamsPlayType                  100.000              4
# specialTeamsResult                    100.000             12
# kickerId                              100.000            111
# returnerId                            100.000            378
# kickBlockerId                         100.000             83
# yardlineSide                          100.000             33
# yardlineNumber                        100.000             50
# gameClock                             100.000            900
# penaltyCodes                          100.000             71
# penaltyJerseyNumbers                  100.000            700
# penaltyYards                          100.000             21
# preSnapHomeScore                      100.000             54
# preSnapVisitorScore                   100.000             55
# passResult                            100.000              4
# kickLength                            100.000             79
# kickReturnYardage                     100.000            106
# playResult                            100.000            116
# absoluteYardlineNumber                100.000             99
#
#                                     Mean  ...  \
# gameId                 2,019,113,760.033  ...
# playId                         2,037.558  ...
# playDescription                      nan  ...
# quarter                            2.484  ...
# down                               1.707  ...
# yardsToGo                          3.750  ...
# possessionTeam                       nan  ...
# specialTeamsPlayType                 nan  ...
# specialTeamsResult                   nan  ...
# kickerId                      41,354.004  ...
# returnerId                           nan  ...
# kickBlockerId                 43,612.469  ...
# yardlineSide                         nan  ...
# yardlineNumber                    28.750  ...
# gameClock                            nan  ...
# penaltyCodes                         nan  ...
# penaltyJerseyNumbers                 nan  ...
# penaltyYards                       3.918  ...
# preSnapHomeScore                  12.209  ...
# preSnapVisitorScore               11.566  ...
# passResult                           nan  ...
# kickLength                        54.744  ...
# kickReturnYardage                 15.906  ...
# playResult                        27.316  ...
# absoluteYardlineNumber            59.638  ...
#
#                                                             Minimum_Value  \
# gameId                                                  2,018,090,600.000
# playId                                                             35.000
# playDescription         (10:00) A.Cole punts 58 yards to MIN 15, Cente...
# quarter                                                             1.000
# down                                                                0.000
# yardsToGo                                                           0.000
# possessionTeam                                                        ARI
# specialTeamsPlayType                                          Extra Point
# specialTeamsResult                                   Blocked Kick Attempt
# kickerId                                                       21,213.000
# returnerId                                                          29830
# kickBlockerId                                                  33,131.000
# yardlineSide                                                          ARI
# yardlineNumber                                                      1.000
# gameClock                                                        00:00:00
# penaltyCodes                                                          BAT
# penaltyJerseyNumbers                                               ARI 16
# penaltyYards                                                      -15.000
# preSnapHomeScore                                                    0.000
# preSnapVisitorScore                                                 0.000
# passResult                                                              C
# kickLength                                                          2.000
# kickReturnYardage                                                 -16.000
# playResult                                                        -72.000
# absoluteYardlineNumber                                             11.000
#
#                               Quartile 1            Median        Quartile 3  \
# gameId                 2,018,120,208.000 2,019,110,303.000 2,020,100,500.000
# playId                           985.000         2,033.000         3,027.000
# playDescription                      nan               nan               nan
# quarter                            2.000             2.000             3.000
# down                               0.000             0.000             4.000
# yardsToGo                          0.000             0.000             7.000
# possessionTeam                       nan               nan               nan
# specialTeamsPlayType                 nan               nan               nan
# specialTeamsResult                   nan               nan               nan
# kickerId                      38,691.000        42,333.000        45,576.000
# returnerId                           nan               nan               nan
# kickBlockerId                 41,438.250        43,797.000        46,216.500
# yardlineSide                         nan               nan               nan
# yardlineNumber                    16.000            35.000            35.000
# gameClock                            nan               nan               nan
# penaltyCodes                         nan               nan               nan
# penaltyJerseyNumbers                 nan               nan               nan
# penaltyYards                       0.000             9.000            10.000
# preSnapHomeScore                   3.000            10.000            19.000
# preSnapVisitorScore                3.000            10.000            17.000
# passResult                           nan               nan               nan
# kickLength                        43.000            55.000            70.000
# kickReturnYardage                  6.000            15.000            23.000
# playResult                         0.000            39.000            40.000
# absoluteYardlineNumber            45.000            59.000            75.000
#
#                                                                 Max_Value  \
# gameId                                                  2,021,010,315.000
# playId                                                          5,729.000
# playDescription         Z.Gonzalez kicks onside 4 yards from ARI 35 to...
# quarter                                                             5.000
# down                                                                4.000
# yardsToGo                                                          46.000
# possessionTeam                                                        WAS
# specialTeamsPlayType                                                 Punt
# specialTeamsResult                                              Touchback
# kickerId                                                       53,146.000
# returnerId                                                          53098
# kickBlockerId                                                  52,592.000
# yardlineSide                                                          WAS
# yardlineNumber                                                     50.000
# gameClock                                                        15:00:00
# penaltyCodes                                                          WED
# penaltyJerseyNumbers                                               WAS 98
# penaltyYards                                                       18.000
# preSnapHomeScore                                                   56.000
# preSnapVisitorScore                                                59.000
# passResult                                                              S
# kickLength                                                         90.000
# kickReturnYardage                                                 104.000
# playResult                                                         82.000
# absoluteYardlineNumber                                            109.000
#
#                                                                      mode  \
# gameId                                                         2018111900
# playId                                                                 36
# playDescription         W.Lutz kicks 65 yards from NO 35 to end zone, ...
# quarter                                                                 2
# down                                                                    0
# yardsToGo                                                               0
# possessionTeam                                                         NO
# specialTeamsPlayType                                              Kickoff
# specialTeamsResult                                      Kick Attempt Good
# kickerId                                                       45,046.000
# returnerId                                                          35527
# kickBlockerId                                                  42,436.000
# yardlineSide                                                          NYJ
# yardlineNumber                                                         35
# gameClock                                                        15:00:00
# penaltyCodes                                                           OH
# penaltyJerseyNumbers                                               BAL 41
# penaltyYards                                                       10.000
# preSnapHomeScore                                                        0
# preSnapVisitorScore                                                     0
# passResult                                                              C
# kickLength                                                         75.000
# kickReturnYardage                                                   0.000
# playResult                                                              0
# absoluteYardlineNumber                                                 45
#
#                        Coefficeint Of Variance  Total_Outliers  \
# gameId                                   0.000           0.000
# playId                                   0.603           0.000
# playDescription                            nan             nan
# quarter                                  0.447         102.000
# down                                     1.153           0.000
# yardsToGo                                1.512         686.000
# possessionTeam                             nan             nan
# specialTeamsPlayType                       nan             nan
# specialTeamsResult                         nan             nan
# kickerId                                 0.141           0.000
# returnerId                                 nan             nan
# kickBlockerId                            0.088           0.000
# yardlineSide                               nan             nan
# yardlineNumber                           0.375           0.000
# gameClock                                  nan             nan
# penaltyCodes                               nan             nan
# penaltyJerseyNumbers                       nan             nan
# penaltyYards                             2.255           0.000
# preSnapHomeScore                         0.824          82.000
# preSnapVisitorScore                      0.865         234.000
# passResult                                 nan             nan
# kickLength                               0.290           0.000
# kickReturnYardage                        0.827           0.000
# playResult                               0.753           1.000
# absoluteYardlineNumber                   0.400           0.000
#
#                         Min Text Length  Max Text Length
# gameId                              nan              nan
# playId                              nan              nan
# playDescription                  54.000          432.000
# quarter                             nan              nan
# down                                nan              nan
# yardsToGo                           nan              nan
# possessionTeam                    2.000            3.000
# specialTeamsPlayType              4.000           11.000
# specialTeamsResult                6.000           24.000
# kickerId                            nan              nan
# returnerId                          nan              nan
# kickBlockerId                       nan              nan
# yardlineSide                      2.000            3.000
# yardlineNumber                      nan              nan
# gameClock                         8.000            8.000
# penaltyCodes                        nan              nan
# penaltyJerseyNumbers                nan              nan
# penaltyYards                        nan              nan
# preSnapHomeScore                    nan              nan
# preSnapVisitorScore                 nan              nan
# passResult                          nan              nan
# kickLength                          nan              nan
# kickReturnYardage                   nan              nan
# playResult                          nan              nan
# absoluteYardlineNumber              nan              nan
#
# [25 rows x 21 columns]

# %%
plays.head()
# Out:
#        gameId  playId                                    playDescription  \
# 0  2018090600      37  J.Elliott kicks 65 yards from PHI 35 to end zo...
# 1  2018090600     366  (9:20) C.Johnston punts 56 yards to ATL 36, Ce...
# 2  2018090600     658  (5:03) M.Bryant 21 yard field goal is GOOD, Ce...
# 3  2018090600     677  M.Bosher kicks 64 yards from ATL 35 to PHI 1. ...
# 4  2018090600     872  (:33) C.Johnston punts 65 yards to end zone, C...
#
#    quarter  down  yardsToGo possessionTeam specialTeamsPlayType  \
# 0        1     0          0            PHI              Kickoff
# 1        1     4          4            PHI                 Punt
# 2        1     4          3            ATL           Field Goal
# 3        1     0          0            ATL              Kickoff
# 4        1     4         18            PHI                 Punt
#
#   specialTeamsResult   kickerId  ... penaltyJerseyNumbers  penaltyYards  \
# 0          Touchback 44,966.000  ...                  NaN           nan
# 1             Return 45,603.000  ...               PHI 18       -15.000
# 2  Kick Attempt Good 27,091.000  ...                  NaN           nan
# 3             Return 37,267.000  ...                  NaN           nan
# 4          Touchback 45,603.000  ...                  NaN           nan
#
#   preSnapHomeScore  preSnapVisitorScore passResult kickLength  \
# 0                0                    0        NaN     66.000
# 1                0                    0        NaN     56.000
# 2                0                    0        NaN     21.000
# 3                0                    3        NaN     64.000
# 4                0                    3        NaN     65.000
#
#   kickReturnYardage  playResult  absoluteYardlineNumber  len
# 0               nan          40                      45  nan
# 1             5.000          36                      18  nan
# 2               nan           0                      13  nan
# 3            30.000          34                      75  nan
# 4               nan          45                      45  nan
#
# [5 rows x 26 columns]

# %%
datamart = plays.groupby(['gameId','gameClock']).agg({
'preSnapHomeScore': 'diff',
'preSnapVisitorScore': 'diff'})
datamart['preSnapHomeScore'].value_counts()
# Out:
# 0.000     1902
# 1.000     1640
# 7.000      126
# 10.000     110
# 3.000      107
# 17.000      96
# 14.000      89
# 6.000       55
# 13.000      52
# 21.000      44
# 20.000      34
# 24.000      29
# 9.000       25
# 16.000      23
# 28.000      12
# 23.000      10
# 26.000       8
# 12.000       6
# 15.000       6
# 27.000       5
# 19.000       5
# 22.000       3
# 11.000       3
# 35.000       3
# 8.000        2
# -1.000       2
# 5.000        2
# 31.000       2
# 32.000       1
# 2.000        1
# 30.000       1
# Name: preSnapHomeScore, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(plays['playId'],plays['playResult'])
plt.show()

# %%
EDA.dq_check(players,verbose=1)
# Out:
# /Users/alexbott/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#             Data_Type  Populated_Count  Null_Count  %_Populated  Blank  \
# nflId           int32             2732           0      100.000      0
# height         object             2732           0      100.000      0
# weight          int16             2732           0      100.000      0
# birthDate      object             2715          17       99.378      0
# collegeName    object             2724           8       99.707      0
# Position       object             2732           0      100.000      0
# displayName    object             2732           0      100.000      0
#
#              %_Populated_Non_Blank  SingleSpace  %_Populated_Non_Space  \
# nflId                      100.000            0                100.000
# height                     100.000            0                100.000
# weight                     100.000            0                100.000
# birthDate                  100.000            0                100.000
# collegeName                100.000            0                100.000
# Position                   100.000            0                100.000
# displayName                100.000            0                100.000
#
#              Unique_Values       Mean  ...      Minimum_Value Quartile 1  \
# nflId                 2732 44,268.174  ...         21,213.000 41,444.750
# height                  30        nan  ...               5-10        nan
# weight                 187    244.365  ...            153.000    205.000
# birthDate             2035        nan  ...         01/01/1991        nan
# collegeName            322        nan  ...  Abilene Christian        nan
# Position                26        nan  ...                  C        nan
# displayName           2718        nan  ...   A'Shawn Robinson        nan
#
#                 Median  Quartile 3         Max_Value         mode  \
# nflId       44,870.500  46,972.500        53,172.000        42533
# height             nan         nan                79          6-3
# weight         235.000     290.000           380.000          205
# birthDate          nan         nan        1999-11-27   1997-02-14
# collegeName        nan         nan  Youngstown State      Alabama
# Position           nan         nan                WR           WR
# displayName        nan         nan        Ziggy Hood  Chris Jones
#
#             Coefficeint Of Variance  Total_Outliers  Min Text Length  \
# nflId                         0.110          61.000              nan
# height                          nan             nan            2.000
# weight                        0.191           0.000              nan
# birthDate                       nan             nan           10.000
# collegeName                     nan             nan            3.000
# Position                        nan             nan            1.000
# displayName                     nan             nan            7.000
#
#              Max Text Length
# nflId                    nan
# height                 4.000
# weight                   nan
# birthDate             10.000
# collegeName           30.000
# Position               3.000
# displayName           27.000
#
# [7 rows x 21 columns]

# %%
EDA.dq_check(tracking2018,verbose=1)
# Out:
# /Users/alexbott/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#               Data_Type  Populated_Count  Null_Count  %_Populated  Blank  \
# time             object         12777351           0      100.000      0
# x               float32         12777351           0      100.000      0
# y               float32         12777351           0      100.000      0
# s               float32         12777351           0      100.000      0
# a               float32         12777351           0      100.000      0
# dis             float32         12777351           0      100.000      0
# o               float32         12221814      555537       95.652      0
# dir             float32         12221814      555537       95.652      0
# event            object         12777351           0      100.000      0
# nflId           float32         12221814      555537       95.652      0
# displayName      object         12777351           0      100.000      0
# jerseyNumber    float32         12221814      555537       95.652      0
# position         object         12221814      555537       95.652      0
# team             object         12777351           0      100.000      0
# frameId           int16         12777351           0      100.000      0
# gameId            int32         12777351           0      100.000      0
# playId            int16         12777351           0      100.000      0
# playDirection    object         12777351           0      100.000      0
#
#                %_Populated_Non_Blank  SingleSpace  %_Populated_Non_Space  \
# time                         100.000            0                100.000
# x                            100.000            0                100.000
# y                            100.000            0                100.000
# s                            100.000            0                100.000
# a                            100.000            0                100.000
# dis                          100.000            0                100.000
# o                            100.000            0                100.000
# dir                          100.000            0                100.000
# event                        100.000            0                100.000
# nflId                        100.000            0                100.000
# displayName                  100.000            0                100.000
# jerseyNumber                 100.000            0                100.000
# position                     100.000            0                100.000
# team                         100.000            0                100.000
# frameId                      100.000            0                100.000
# gameId                       100.000            0                100.000
# playId                       100.000            0                100.000
# playDirection                100.000            0                100.000
#
#                Unique_Values              Mean  ...            Minimum_Value  \
# time                  525791               nan  ...  2018-09-07T01:05:25.800
# x                      15176            59.147  ...                  -31.420
# y                       7090            27.301  ...                  -16.200
# s                       3634             3.819  ...                    0.000
# a                       3139             1.722  ...                    0.000
# dis                      965             0.389  ...                    0.000
# o                      36001           179.718  ...                    0.000
# dir                    36001           179.731  ...                    0.000
# event                     58               nan  ...                     None
# nflId                   1769        38,362.031  ...               21,213.000
# displayName             1762               nan  ...         A'Shawn Robinson
# jerseyNumber              99            46.291  ...                    1.000
# position                  27               nan  ...                        C
# team                       3               nan  ...                     away
# frameId                  473            47.075  ...                    1.000
# gameId                   253 2,018,107,606.975  ...        2,018,090,600.000
# playId                  3414         2,011.735  ...                   35.000
# playDirection              2               nan  ...                     left
#
#                      Quartile 1            Median        Quartile 3  \
# time                        nan               nan               nan
# x                        40.090            59.720            79.200
# y                        21.360            26.760            32.210
# s                         0.830             3.310             6.480
# a                         0.630             1.410             2.490
# dis                       0.090             0.330             0.650
# o                        90.000           180.540           269.800
# dir                      89.980           180.490           269.900
# event                       nan               nan               nan
# nflId                40,473.000        43,398.000        45,216.000
# displayName                 nan               nan               nan
# jerseyNumber             28.000            43.000            57.000
# position                    nan               nan               nan
# team                        nan               nan               nan
# frameId                  21.000            41.000            67.000
# gameId        2,018,100,700.000 2,018,110,405.000 2,018,120,213.000
# playId                  951.000         2,004.000         3,010.000
# playDirection               nan               nan               nan
#
#                              Max_Value                     mode  \
# time           2018-12-31T04:20:19.900  2018-12-30T21:25:33.500
# x                              146.650                   43.780
# y                               88.890                   26.830
# s                               48.320                    0.000
# a                               63.780                    0.000
# dis                             53.070                    0.000
# o                              360.000                   90.000
# dir                            360.000                   90.000
# event                          xp_fake                     None
# nflId                       47,016.000               46,657.000
# displayName                   football                 football
# jerseyNumber                    99.000                   36.000
# position                            WR                       CB
# team                              home                     away
# frameId                        473.000                        1
# gameId               2,018,123,015.000               2018102107
# playId                       5,706.000                       36
# playDirection                    right                    right
#
#               Coefficeint Of Variance  Total_Outliers  Min Text Length  \
# time                              nan             nan           23.000
# x                               0.406         192.000              nan
# y                               0.361     440,227.000              nan
# s                               0.896      94,902.000              nan
# a                               0.898     288,785.000              nan
# dis                             0.921     129,737.000              nan
# o                               0.550           0.000              nan
# dir                             0.549           0.000              nan
# event                             nan             nan            3.000
# nflId                           0.144           0.000              nan
# displayName                       nan             nan            8.000
# jerseyNumber                    0.520           0.000              nan
# position                          nan             nan            1.000
# team                              nan             nan            4.000
# frameId                         0.717     147,913.000              nan
# gameId                          0.000           0.000              nan
# playId                          0.611           0.000              nan
# playDirection                     nan             nan            4.000
#
#                Max Text Length
# time                    23.000
# x                          nan
# y                          nan
# s                          nan
# a                          nan
# dis                        nan
# o                          nan
# dir                        nan
# event                   24.000
# nflId                      nan
# displayName             27.000
# jerseyNumber               nan
# position                 3.000
# team                     8.000
# frameId                    nan
# gameId                     nan
# playId                     nan
# playDirection            5.000
#
# [18 rows x 21 columns]

# %% [markdown]
# This shows the dataset set to be massive therefore as thid is supposed to be a 6 week project probably best to go for quality over quantity.

# %% [markdown]
# **Viewing data**
#
# trying to spot anything that needs cleaning

# %%
# shows the first n rows of the data, can change this by changing the n value
# plays.head()

# %% [markdown]
# **Cleaning data**
#
# The 'birthDate' and 'collegeName' columns of 'players.csv' have missing values
#
# Need to convert 'height' column values from 'players.csv' from the format feet-inch or inch to feet to allow for calculations etc
#
# The 'birthDate' column should be parsed as DateTime instead of object?
#
# Need to split YYYY (Year) from YYYY-MM-DD date format to allow for calculations etc
#
# Replace abbrevated words with keywords in general, for example position of type of kick
#
# Remove null values from the dataset for calculations etc

# %% [markdown]
# **Cleaning scouting**

# %%
scouting.head()
# Out:
#        gameId  playId snapDetail  snapTime  operationTime  hangTime kickType  \
# 0  2018090600      37        NaN       NaN            NaN      3.85        D
# 1  2018090600     366         OK      0.84           2.12      4.46        N
# 2  2018090600     658        NaN       NaN            NaN       NaN      NaN
# 3  2018090600     677        NaN       NaN            NaN      4.06        D
# 4  2018090600     872         OK      0.84           2.00      4.35        N
#
#   kickDirectionIntended kickDirectionActual returnDirectionIntended  \
# 0                     R                   R                     NaN
# 1                     C                   C                       C
# 2                   NaN                 NaN                     NaN
# 3                     R                   R                       C
# 4                     C                   L                     NaN
#
#   returnDirectionActual missedTackler assistTackler tackler  \
# 0                   NaN           NaN           NaN     NaN
# 1                     R        PHI 57           NaN  PHI 54
# 2                   NaN           NaN           NaN     NaN
# 3                     C        ATL 83        ATL 22  ATL 27
# 4                   NaN           NaN           NaN     NaN
#
#   kickoffReturnFormation         gunners puntRushers specialTeamsSafeties  \
# 0                  8-0-2             NaN         NaN       PHI 23; PHI 27
# 1                    NaN  PHI 18; PHI 29         NaN                  NaN
# 2                    NaN             NaN         NaN               PHI 58
# 3                  8-0-2             NaN         NaN       ATL 17; ATL 22
# 4                    NaN  PHI 18; PHI 29      ATL 85               ATL 37
#
#                             vises kickContactType
# 0                             NaN             NaN
# 1  ATL 83; ATL 27; ATL 34; ATL 21              CC
# 2                             NaN             NaN
# 3                             NaN             NaN
# 4          ATL 83; ATL 34; ATL 21              BF

# %% [markdown]
# converting letters to names (this can be generalised)

# %%
# converting letters to names (this can be generalised)
# 'kickType': abbreviated
kick_types = ['D','F','K','O','P','Q','S','B','N','R','A']
# kick type full names
kick_type_names = ['Deep','Flat','Free','Obvious','Pooch','Squib','Surprise','Deep','Normal','Rugby','Aussie']
# new names
kick_type_name = []
# looping through
for i in scouting["kickType"]:
  # filtering out NaN values
  if i in kick_types:
    index = kick_types.index(i)
    kick_type_name.append(kick_type_names[index])
  else:
    kick_type_name.append(i)
scouting["kick_type_name"] = kick_type_name

# %%
# new look at data
scouting[['kickType','kick_type_name']].head()
# have left NaN values in at the moment
# Out:
#   kickType kick_type_name
# 0        D           Deep
# 1        N         Normal
# 2      NaN            NaN
# 3        D           Deep
# 4        N         Normal

# %% [markdown]
# **Creating function to change abbrvs**

# %%
def abbrvs(csv,column,abbrv,fullname):
  # new names
  type_name = []
  # looping through
  for i in csv[column]:
    # filtering out NaN values
    if i in abbrv:
      index = abbrv.index(i)
      type_name.append(fullname[index])
    else:
      type_name.append(i)
  return type_name

# %%
# testing function
# inputs
csv = scouting
column = "kickType"
kick_types = ['D','F','K','O','P','Q','S','B','N','R','A']
kick_type_names = ['Deep','Flat','Free','Obvious','Pooch','Squib','Surprise','Deep','Normal','Rugby','Aussie']
# calling function
kick_type_fullnames = abbrvs(csv,column,kick_types,kick_type_names)
# viewing
kick_type_fullnames[0:5]
# Out:
# ['Deep', 'Normal', nan, 'Deep', 'Normal']

# %% [markdown]
# splitting 'missedTackler' to team and number (can be generalised for other variables)

# %%
# splitting 'missedTackler' to team and number (can be generalised for other variables)
missed_tackler_split_team = []
missed_tackler_split_numbers = []
# splitting the data
missed_tackler_split = scouting["missedTackler"].str.split("; ", expand = True)
# loop for each
for i in range(0,len(scouting)):
  # specific data
  missed_tackler_split.iloc[i]
  # number of NaN
  nan_num = missed_tackler_split.iloc[i].isna().sum()
  if 5-nan_num == 0:
    missed_tackler_split_team.append(scouting['missedTackler'][i])
    missed_tackler_split_numbers.append(scouting['missedTackler'][i])
  else:
    info = []
    for j in range(0,(5-nan_num)):
      missed_tackler_split_i = missed_tackler_split[j][i].split(" ")
      info.append(missed_tackler_split_i)
    # team name
    missed_tackler_split_team.append(info[0][0])
    # numbers
    nums = []
    for k in range(0,5-nan_num):
      num = info[k][1]
      nums.append(num)
    missed_tackler_split_numbers.append(nums)
# adding new columns
scouting["missed_tackler_team"] = missed_tackler_split_team
scouting["missed_tackler_numbers"] = missed_tackler_split_numbers

# %%
# new look at data
scouting[['missedTackler','missed_tackler_team','missed_tackler_numbers']].head()
# Out:
#   missedTackler missed_tackler_team missed_tackler_numbers
# 0           NaN                 NaN                    NaN
# 1        PHI 57                 PHI                   [57]
# 2           NaN                 NaN                    NaN
# 3        ATL 83                 ATL                   [83]
# 4           NaN                 NaN                    NaN

# %% [markdown]
# probably a better way so no lists in numbers column

# %% [markdown]
# **Creating definition to use for team and number splitting**

# %%
def team_number_splitting(csv,column,symbol):
  # splitting to team and number
  split_team = []
  split_numbers = []
  # splitting the data
  split = csv[column].str.split(symbol, expand = True)
  # loop for each
  for i in range(0,len(csv)):
    # specific data
    split.iloc[i]
    # number of NaN
    nan_num = split.iloc[i].isna().sum()
    if 5-nan_num == 0:
      split_team.append(csv[column][i])
      split_numbers.append(csv[column][i])
    else:
      info = []
      for j in range(0,(5-nan_num)):
        split_i = split[j][i].split(" ")
        info.append(split_i)
      # team name
      split_team.append(info[0][0])
      # numbers
      nums = []
      for k in range(0,5-nan_num):
        num = info[k][1]
        nums.append(num)
      split_numbers.append(nums)
  return split_team,split_numbers

# %%
# testing
# inputs
csv = scouting
column = "missedTackler"
symbol = "; "
# calling function
missed_tackler_team, missed_tackler_numbers = team_number_splitting(csv,column,symbol)
# looking at data
print(missed_tackler_team[0:5])
print(missed_tackler_numbers[0:5])
# Out:
# [nan, 'PHI', nan, 'ATL', nan]
# [nan, ['57'], nan, ['83'], nan]

# %% [markdown]
# 'kickoffReturnFormation' to numerical

# %%
# 'kickoffReturnFormation' to numberic
# splitting the numbers
formation_split = scouting["kickoffReturnFormation"].str.split("-", n = 2, expand = True)
# new column names
formation_split.columns = ['Front','Mid','Back']
# adding new columns
scouting["formation_front"] = pd.to_numeric(formation_split["Front"])
scouting["formation_mid"] = pd.to_numeric(formation_split["Mid"])
scouting["formation_back"] = pd.to_numeric(formation_split["Back"])

# %% [markdown]
# **Creating definition to use for number splitting**

# %%
def number_splitting(csv,column,symbol,n):
  split = csv[column].str.split(symbol, n = n, expand = True)
  return split

# %%
# testing
# inputs
csv = scouting
column = "kickoffReturnFormation"
symbol = "-"
n = 2
# calling function
formation_split = number_splitting(csv,column,symbol,n)
# looking at data
formation_split.head()
# Out:
#      0    1    2
# 0    8    0    2
# 1  NaN  NaN  NaN
# 2  NaN  NaN  NaN
# 3    8    0    2
# 4  NaN  NaN  NaN

# %%
def pd_to_num(csv,split,column_names):
  split.columns = column_names
  # adding columns
  for name in column_names:
    csv[name] = pd.to_numeric(split[name])
  return

# %%
column_names = ['Front','Mid','Back']
csv = scouting
column = "kickoffReturnFormation"
symbol = "-"
n = 2
# calling function
formation_split = number_splitting(csv,column,symbol,n)
# calling function
pd_to_num(csv,formation_split,column_names)
# viewing 
scouting.head()
# Out:
#        gameId  playId snapDetail  snapTime  operationTime  hangTime kickType  \
# 0  2018090600      37        NaN       NaN            NaN      3.85        D
# 1  2018090600     366         OK      0.84           2.12      4.46        N
# 2  2018090600     658        NaN       NaN            NaN       NaN      NaN
# 3  2018090600     677        NaN       NaN            NaN      4.06        D
# 4  2018090600     872         OK      0.84           2.00      4.35        N
#
#   kickDirectionIntended kickDirectionActual returnDirectionIntended  ...  \
# 0                     R                   R                     NaN  ...
# 1                     C                   C                       C  ...
# 2                   NaN                 NaN                     NaN  ...
# 3                     R                   R                       C  ...
# 4                     C                   L                     NaN  ...
#
#   kickContactType kick_type_name missed_tackler_team missed_tackler_numbers  \
# 0             NaN           Deep                 NaN                    NaN
# 1              CC         Normal                 PHI                   [57]
# 2             NaN            NaN                 NaN                    NaN
# 3             NaN           Deep                 ATL                   [83]
# 4              BF         Normal                 NaN                    NaN
#
#   formation_front formation_mid formation_back Front  Mid Back
# 0             8.0           0.0            2.0   8.0  0.0  2.0
# 1             NaN           NaN            NaN   NaN  NaN  NaN
# 2             NaN           NaN            NaN   NaN  NaN  NaN
# 3             8.0           0.0            2.0   8.0  0.0  2.0
# 4             NaN           NaN            NaN   NaN  NaN  NaN
#
# [5 rows x 29 columns]

# %%
# new look at data
scouting[['kickoffReturnFormation','formation_front','formation_mid','formation_back']].head()
# Out:
#   kickoffReturnFormation  formation_front  formation_mid  formation_back
# 0                  8-0-2              8.0            0.0             2.0
# 1                    NaN              NaN            NaN             NaN
# 2                    NaN              NaN            NaN             NaN
# 3                  8-0-2              8.0            0.0             2.0
# 4                    NaN              NaN            NaN             NaN

# %%
#
# have created all 3 methods needed to clean scouting.csv, just have to change variable names etc
#

# %% [markdown]
# **Cleaning games**

# %%
games.head()
# Out:
#        gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0  2018090600    2018     1  09/06/2018        20:20:00          PHI
# 1  2018090900    2018     1  09/09/2018        13:00:00          BAL
# 2  2018090901    2018     1  09/09/2018        13:00:00          CLE
# 3  2018090902    2018     1  09/09/2018        13:00:00          IND
# 4  2018090903    2018     1  09/09/2018        13:00:00          MIA
#
#   visitorTeamAbbr
# 0             ATL
# 1             BUF
# 2             PIT
# 3             CIN
# 4             TEN

# %% [markdown]
# splitting the game date into day, month and year

# %%
# splitting gameDate
# splitting the numbers
game_date_split = games["gameDate"].str.split("/", n = 2, expand = True)
# new column names
game_date_split.columns = ['Month','Day','Year']
# adding new columns
games["game_date_day"] = pd.to_numeric(game_date_split["Day"])
games["game_date_month"] = pd.to_numeric(game_date_split["Month"])
games["game_date_year"] = pd.to_numeric(game_date_split["Year"])

# %%
# new look at data
games[['gameDate','game_date_day','game_date_month','game_date_year']].head()
# Out:
#      gameDate  game_date_day  game_date_month  game_date_year
# 0  09/06/2018              6                9            2018
# 1  09/09/2018              9                9            2018
# 2  09/09/2018              9                9            2018
# 3  09/09/2018              9                9            2018
# 4  09/09/2018              9                9            2018

# %% [markdown]
# spltting game time

# %%
# splitting gameTimeEastern
# splitting the numbers
game_time_split = games["gameTimeEastern"].str.split(":", n = 2, expand = True)
# new column names
game_time_split.columns = ['Hour','Minute','Second']
# adding new columns
games["game_time_hour"] = pd.to_numeric(game_time_split["Hour"])
games["game_time_minute"] = pd.to_numeric(game_time_split["Minute"])
games["game_time_second"] = pd.to_numeric(game_time_split["Second"])

# %%
# new look at data
games[['gameTimeEastern','game_time_hour','game_time_minute','game_time_second']].head()
# Out:
#   gameTimeEastern  game_time_hour  game_time_minute  game_time_second
# 0        20:20:00              20                20                 0
# 1        13:00:00              13                 0                 0
# 2        13:00:00              13                 0                 0
# 3        13:00:00              13                 0                 0
# 4        13:00:00              13                 0                 0

# %%
#
# games.csv in clean except from the Abbr words of the teams
#

# %% [markdown]
# **Cleaning players**

# %%
players.head()
# Out:
#    nflId height  weight   birthDate       collegeName Position  \
# 0  42901    6-1     208  1992-07-25     James Madison       SS
# 1  43501    6-0     220  1994-08-11  Central Michigan       FS
# 2  43534    6-0     205  1993-06-02          Illinois       SS
# 3  43535    6-1     235  1992-12-22            Temple      MLB
# 4  44174    6-1     236  1993-02-22        Texas Tech      ILB
#
#          displayName
# 0       Dean Marlowe
# 1      Kavon Frazier
# 2  Clayton Fejedelem
# 3   Tyler Matakevich
# 4       Sam Eguavoen

# %% [markdown]
# changing height to numerical values

# %%
# changing height to numerical values
# splitting the heights
height_split = players["height"].str.split("-", n = 1, expand = True)
# new column names
height_split.columns = ['Feet', 'Inch']
# adding new columns
players["height_feet"] = pd.to_numeric(height_split["Feet"])
players["height_inch"] = pd.to_numeric(height_split["Inch"])

# %%
# new look at data
players[['height','height_feet','height_inch']].head()
# Out:
#   height  height_feet  height_inch
# 0    6-1            6          1.0
# 1    6-0            6          0.0
# 2    6-0            6          0.0
# 3    6-1            6          1.0
# 4    6-1            6          1.0

# %%
# still have 73 feet
# getting rid of NaN values
players["height_inch"] = players["height_inch"].fillna(0)
# replacing heights that did not have '-' at start
for i in players["height_feet"]:
    if i > 7:
        j = 0.0833333 * i
        players["height_feet"].replace({i : j}, inplace=True)        
# inches to numerical value
players["height_inch"] = 0.0833333 * players["height_inch"]

# %%
# adding feet and inches to get one value
height_numerical = players["height_feet"] + players["height_inch"]
# adding new numerical value column
players["height_numerical"] = pd.to_numeric(height_numerical)

# %%
# new look at data
players[['height','height_numerical']].head()
# Out:
#   height  height_numerical
# 0    6-1          6.083333
# 1    6-0          6.000000
# 2    6-0          6.000000
# 3    6-1          6.083333
# 4    6-1          6.083333

# %% [markdown]
# getting year from 'birthDate'

# %%
# splitting the numbers
players['birth_year'] = pd.DatetimeIndex(players['birthDate']).year

# %%
# new look at data
players[['birthDate','birth_year']].head()
# Out:
#     birthDate  birth_year
# 0  1992-07-25      1992.0
# 1  1994-08-11      1994.0
# 2  1993-06-02      1993.0
# 3  1992-12-22      1992.0
# 4  1993-02-22      1993.0

# %%
#
# players.csv is clean, habe left NaN values in
#

# %% [markdown]
# **Cleaning plays**

# %%
plays.head()
# Out:
#        gameId  playId                                    playDescription  \
# 0  2018090600      37  J.Elliott kicks 65 yards from PHI 35 to end zo...
# 1  2018090600     366  (9:20) C.Johnston punts 56 yards to ATL 36, Ce...
# 2  2018090600     658  (5:03) M.Bryant 21 yard field goal is GOOD, Ce...
# 3  2018090600     677  M.Bosher kicks 64 yards from ATL 35 to PHI 1. ...
# 4  2018090600     872  (:33) C.Johnston punts 65 yards to end zone, C...
#
#    quarter  down  yardsToGo possessionTeam specialTeamsPlayType  \
# 0        1     0          0            PHI              Kickoff
# 1        1     4          4            PHI                 Punt
# 2        1     4          3            ATL           Field Goal
# 3        1     0          0            ATL              Kickoff
# 4        1     4         18            PHI                 Punt
#
#   specialTeamsResult  kickerId  ... penaltyCodes  penaltyJerseyNumbers  \
# 0          Touchback   44966.0  ...          NaN                   NaN
# 1             Return   45603.0  ...         UNSd                PHI 18
# 2  Kick Attempt Good   27091.0  ...          NaN                   NaN
# 3             Return   37267.0  ...          NaN                   NaN
# 4          Touchback   45603.0  ...          NaN                   NaN
#
#   penaltyYards  preSnapHomeScore preSnapVisitorScore passResult kickLength  \
# 0          NaN                 0                   0        NaN       66.0
# 1        -15.0                 0                   0        NaN       56.0
# 2          NaN                 0                   0        NaN       21.0
# 3          NaN                 0                   3        NaN       64.0
# 4          NaN                 0                   3        NaN       65.0
#
#    kickReturnYardage  playResult  absoluteYardlineNumber
# 0                NaN          40                      45
# 1                5.0          36                      18
# 2                NaN           0                      13
# 3               30.0          34                      75
# 4                NaN          45                      45
#
# [5 rows x 25 columns]

# %% [markdown]
# cleaning gameClock to numbers

# %%
# splitting the numbers
game_clock_split = plays["gameClock"].str.split(":", n = 2, expand = True)
# new column names
game_clock_split.columns = ['Minute','Second','Milli']
# adding new columns
plays["game_clock_minute"] = pd.to_numeric(game_clock_split["Minute"])
plays["game_clock_second"] = pd.to_numeric(game_clock_split["Second"])
plays["game_clock_milli"] = pd.to_numeric(game_clock_split["Milli"])

# %%
# new look at code
plays[['gameClock','game_clock_minute','game_clock_second']].head()
# Out:
#   gameClock  game_clock_minute  game_clock_second
# 0  15:00:00                 15                  0
# 1  09:20:00                  9                 20
# 2  05:03:00                  5                  3
# 3  05:01:00                  5                  1
# 4  00:33:00                  0                 33

# %% [markdown]
# **Cleaning tracking**

# %%
tracking2018.head()
# do not forget there's 3 seasons
# Out:
#                       time      x      y     s     a   dis       o     dir  \
# 0  2018-12-30T21:25:32.200  41.32  29.45  4.36  1.33  0.43  130.42  128.44
# 1  2018-12-30T21:25:32.300  41.68  29.17  4.59  1.24  0.45  128.59  127.81
# 2  2018-12-30T21:25:32.400  42.05  28.88  4.74  0.99  0.47  124.47  128.15
# 3  2018-12-30T21:25:32.500  42.43  28.59  4.87  0.71  0.48  126.02  127.35
# 4  2018-12-30T21:25:32.600  42.84  28.31  4.96  0.79  0.50  131.71  124.75
#
#   event    nflId    displayName  jerseyNumber position  team  frameId  \
# 0  None  39470.0  Justin Tucker           9.0        K  home        1
# 1  None  39470.0  Justin Tucker           9.0        K  home        2
# 2  None  39470.0  Justin Tucker           9.0        K  home        3
# 3  None  39470.0  Justin Tucker           9.0        K  home        4
# 4  None  39470.0  Justin Tucker           9.0        K  home        5
#
#        gameId  playId playDirection
# 0  2018123000      36         right
# 1  2018123000      36         right
# 2  2018123000      36         right
# 3  2018123000      36         right
# 4  2018123000      36         right

# %%
seasons = [2018, 2019, 2020]

# %%
#
# generally looks pretty clean already
#

# %% [markdown]
# **Extracting specific data**

# %%
# x and y positions of players
x = tracking2018['x']
y = tracking2018['y']

# getting specific play and player, x and y
nfl_id = 39470
display_name = "Justin Tucker"

x_nfl_id_name = tracking2018.loc[((tracking2018["nflId"] == nfl_id) & (tracking2018["displayName"] == display_name)), "x"]
y_nfl_id_name = tracking2018.loc[((tracking2018["nflId"] == nfl_id) & (tracking2018["displayName"] == display_name)), "y"]

x_nfl_id_name.head()
# Out:
# 0    41.32
# 1    41.68
# 2    42.05
# 3    42.43
# 4    42.84
# Name: x, dtype: float64

# %% [markdown]
# **Drawing pitch**

# %%
import matplotlib.patches as patches
from matplotlib.patches import Arc
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches

# Change size of the figure
plt.rcParams['figure.figsize'] = [12, 8]
def drawPitch(width, height, color="w"):
    fig = plt.figure()
    ax = plt.axes(xlim=(-10, width + 30), ylim=(-15, height + 5))
    plt.axis('off')

    # Grass around pitch
    rect = patches.Rectangle((-10, -5), width + 40, height + 10, linewidth=1, facecolor='darkgreen', capstyle='round') # facecolor='#3f995b'
    ax.add_patch(rect)
    ###################

    # Pitch boundaries
    rect = plt.Rectangle((0, 0), width + 20, height, ec=color, fc="None", lw=2)
    ax.add_patch(rect)
    ###################

    # vertical lines - every 5 yards
    for i in range(21):
        plt.plot([10 + 5 * i, 10 + 5 * i], [0, height], c="w", lw=2)
    ###################
        
    # distance markers - every 10 yards
    for yards in range(10, width, 10):
        yards_text = yards if yards <= width / 2 else width - yards
        # top markers
        plt.text(10 + yards - 2, height - 7.5, yards_text, size=15, c="w", weight="bold")
        # botoom markers
        plt.text(10 + yards - 2, 7.5, yards_text, size=15, c="w", weight="bold", rotation=180)
    ###################

    # yards markers - every yard
    # bottom markers
    for x in range(20):
        for j in range(1, 5):
            plt.plot([10 + x * 5 + j, 10 + x * 5 + j], [1, 3], color="w", lw=2)

    # top markers
    for x in range(20):
        for j in range(1, 5):
            plt.plot([10 + x * 5 + j, 10 + x * 5 + j], [height - 1, height - 3], color="w", lw=2)

    # middle bottom markers
    y = (height - 18.5) / 2
    for x in range(20):
        for j in range(1, 5):
            plt.plot([10 + x * 5 + j, 10 + x * 5 + j], [y, y + 2], color="w", lw=2)

    # middle top markers
    for x in range(20):
        for j in range(1, 5):
            plt.plot([10 + x * 5 + j, 10 + x * 5 + j], [height - y, height - y - 2], color="w", lw=2)
    ###################

    # draw home end zone
    plt.text(2.5, (height - 15) / 2, "HOME", size=30, c="w", weight="bold", rotation=90)
    rect = plt.Rectangle((0, 0), 10, height, ec=color, fc="#0064dc", lw=2)
    ax.add_patch(rect)

    # draw away end zone    
    plt.text(111, (height - 15) / 2, "AWAY", size=30, c="w", weight="bold", rotation=-90)
    rect = plt.Rectangle((width + 10, 0), 10, height, ec=color, fc="#c80014", lw=2)
    ax.add_patch(rect)
    ###################
    
    # draw extra spot point
    # left
    y = (height - 3) / 2
    plt.plot([10 + 2, 10 + 2], [y, y + 3], c="w", lw=2)
    
    # right
    plt.plot([width + 10 - 2, width + 10 - 2], [y, y + 3], c="w", lw=2)
    ###################
    
    # draw goalpost
    goal_width = 6 # yards
    y = (height - goal_width) / 2
    # left
    plt.plot([0, 0], [y, y + goal_width], "-", c="y", lw=10, ms=20)
    # right
    plt.plot([width + 20, width + 20], [y, y + goal_width], "-", c="y", lw=10, ms=20)
    
    return fig, ax
fig, ax = drawPitch(100, 53.3)

# %% [markdown]
# **Plotting on field**

# %%
#imports
import numpy as np
from matplotlib import pyplot as plt
# drawing pitch
fig, ax = drawPitch(100, 53.3)
# getting specific x and y
nfl_id = 39470
display_name = "Justin Tucker"

#x_nfl_id = tracking2018.loc[tracking2018["nflId"] == nfl_id, "x"]
#y_nfl_id = tracking2018.loc[tracking2018["nflId"] == nfl_id, "y"]

x_name = tracking2018.loc[(tracking2018["displayName"] == display_name), "x"]
y_name = tracking2018.loc[(tracking2018["displayName"] == display_name), "y"]

x_pos = x[0:105] 
y_pos = y[0:105]

# plotting
#ax.plot(x_pos, y_pos, ls='dotted', linewidth=3, color='red')
tracking2018.query('gameId == 2018123000 and playId == 36').groupby('team')\
.plot(x='x', y='y', ax=ax, style='.')
# showing
plt.show()

# thoughts on this: 
# 1. obvs when image is blown up it will look crap therefore need to think of something
# 2. would work well with showing pass and the direction etc
# 3. could use it to show simulations of the 'ball' moving in different plays in vid presentation

# %% [markdown]
# **Simulating on NFL field image**

# %%
def extract_one_game(game_id, play_id, df):
    game = df[(df.gameId == game_id) & (df.playId == play_id)]
    home = {}
    away = {}
    balls = []
    
    players = game.sort_values(['frameId'], ascending=True).groupby('nflId')
    for id, dx in players:
        jerseyNumber = int(dx.jerseyNumber.iloc[0])
        if dx.team.iloc[0] == "home":
            home[jerseyNumber] = list(zip(dx.x.tolist(), dx.y.tolist()))
        elif dx.team.iloc[0] == "away":
            away[jerseyNumber] = list(zip(dx.x.tolist(), dx.y.tolist()))


    ball_df = game.sort_values(['frameId'], ascending=True) 
    ball_df = ball_df[ball_df.team == "football"]
    balls = list(zip(ball_df.x.tolist(), ball_df.y.tolist()))
    return home, away, balls

# %%
from matplotlib import animation
from IPython.display import HTML
def animate_one_play(game_id, play_id, df):
    fig, ax = drawPitch(100, 53.3)
    
    home, away, balls = extract_one_game(game_id, play_id, df)

    team_left, = ax.plot([], [], 'o', markersize=20, markerfacecolor="r", markeredgewidth=2, markeredgecolor="white", zorder=7)
    team_right, = ax.plot([], [], 'o', markersize=20, markerfacecolor="b", markeredgewidth=2, markeredgecolor="white", zorder=7)
    ball, = ax.plot([], [], 'o', markersize=10, markerfacecolor="black", markeredgewidth=2, markeredgecolor="white", zorder=7)
    drawings = [team_left, team_right, ball]

    def init():
        team_left.set_data([], [])
        team_right.set_data([], [])
        ball.set_data([], [])
        return drawings

    def draw_teams(i):
        X = []
        Y = []
        for k, v in home.items():
            x, y = v[i]
            X.append(x)
            Y.append(y)
        team_left.set_data(X, Y)
        
        X = []
        Y = []
        for k, v in away.items():
            x, y = v[i]
            X.append(x)
            Y.append(y)
        team_right.set_data(X, Y)

    def animate(i):
        draw_teams(i)
        
        x, y = balls[i]
        ball.set_data([x, y])
        return drawings
    
    # !May take a while!
    anim = animation.FuncAnimation(fig, animate, init_func=init,
                                   frames=len(balls), interval=100, blit=True)

    return HTML(anim.to_html5_video())

# %%
# game_id, play_id, df
animate_one_play(2018123000, 36, tracking2018)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-47-5a25b9e0624c> in <module>
#       1 # game_id, play_id, df
# ----> 2 animate_one_play(2018123000, 36, tracking2018)
#
# <ipython-input-46-b0b21e901286> in animate_one_play(game_id, play_id, df)
#      45                                    frames=len(balls), interval=100, blit=True)
#      46
# ---> 47     return HTML(anim.to_html5_video())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1326                 # We create a writer manually so that we can get the
#    1327                 # appropriate size for the tag
# -> 1328                 Writer = writers[rcParams['animation.writer']]
#    1329                 writer = Writer(codec='h264',
#    1330                                 bitrate=rcParams['animation.bitrate'],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     162         if self.is_available(name):
#     163             return self._registered[name]
# --> 164         raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#     165
#     166
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %% [markdown]
# **This code can do the simulation in VS Code without a problem**

# %%
# # imports 
# import numpy as np
# import matplotlib.pyplot as plt
# # input data
# x_pos = x[0:105]
# y_pos = y[0:105]
# # animating plot
# fig, ax = plt.subplots()
# for i in range(len(x_pos)):
#     # plotting field image
#     plt.rcParams["figure.figsize"] = [5.33, 12] # used [5.33,12] as pitch has dimensions [53.3,120]
#     plt.rcParams["figure.autolayout"] = True
#     im = plt.imread("pitch.jpg")
#     # fig and ax plots
#     im = ax.imshow(im,extent=[0, 120, 0, 53.3]) # respect to size of the field [53.3,120]
#     # plotting
#     ax.plot(x_pos[:i], y_pos[:i], ls='dotted', linewidth=1, color='red')
#     # labels
#     plt.xlabel('Home Sideline')
#     plt.ylabel('Home Endzone')
#     # pausing
#     plt.pause(0.01) # the ten times a second combo
# # showing
# plt.show()

# %% [markdown]
# **New simulation**

# %%
import plotly.graph_objects as go
import plotly.express as px
# play
play_2020091000_39 = tracking2020.loc[(tracking2020['playId'] == 3509) & (tracking2020['gameId'] == 2020091310)]

fig = go.Figure()

fig = px.scatter(play_2020091000_39, 
           x="x", 
           y="y", 
           animation_frame="time", 
           animation_group="nflId",
           color="team",
           hover_name="displayName", 
          )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="98ecfecc-823c-4a48-ad88-33ee1178f81c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98ecfecc-823c-4a48-ad88-33ee1178f81c")) {                    Plotly.newPlot(                        "98ecfecc-823c-4a48-ad88-33ee1178f81c",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>team=home<br>time=2020-09-13T23:05:26.700<br>x=%{x}<br>y=%{y}<extra></extra>","hovertext":["Thomas Morstead","Patrick Robinson","Craig Robertson","D.J. Swearinger","Bennie Fowler","Ty Montgomery","Justin Hardee","J.T. Gray","Chauncey Gardner-Johnson","Kaden Elliss","Carl Granderson"],"ids":[34615.0,35471.0,38470.0,40005.0,41507.0,42437.0,45648.0,46378.0,47888.0,48027.0,48537.0],"legendgroup":"home","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"home","orientation":"v","showlegend":true,"x":[58.73,58.57,58.27,59.3,58.37,58.5,58.63,58.37,58.63,58.53,58.6],"xaxis":"x","y":[33.43,42.43,46.67,29.27,7.43,15.67,37.77,35.97,4.97,20.7,11.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>team=away<br>time=2020-09-13T23:05:26.700<br>x=%{x}<br>y=%{y}<extra></extra>","hovertext":["Kevin Minter","Ryan Smith","Andrew Adams","Jaydon Mickens","Antony Auclair","Justin Watson","Jack Cichy","Jamel Dean","Mike Edwards","Anthony Nelson","Quinton Bell"],"ids":[39993.0,43397.0,43757.0,44029.0,45321.0,46213.0,46271.0,47877.0,47882.0,47890.0,48013.0],"legendgroup":"away","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"away","orientation":"v","showlegend":true,"x":[70.54,70.34,70.95,100.03,79.3,99.07,70.41,70.8,79.1,78.97,70.7],"xaxis":"x","y":[14.26,6.06,20.49,14.13,24.64,35.52,37.4,45.09,13.14,38.19,29.31],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>team=football<br>time=2020-09-13T23:05:26.700<br>x=%{x}<br>y=%{y}<extra></extra>","hovertext":["football"],"ids":[null],"legendgroup":"football","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"football","orientation":"v","showlegend":true,"x":[59.85],"xaxis":"x","y":[29.72],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale" ...

# %% [markdown]
# **1. Different kick types and there hang times**

# %%
import statistics as stats
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

kick_types = ['D','F','K','O','P','Q','S','B','N','R','A']

kick_type_names = ['Deep','Flat','Free','Obvious','Pooch','Squib','Surprise','Deep','Normal','Rugby','Aussie']

plt.figure(figsize=(10, 6))
# loop
for kick_type in kick_types:
  # finding full name
  index = kick_types.index(kick_type)
  # getting data
  kick_data = scouting.loc[(scouting["kickType"] == kick_type), "hangTime"]
  # plotting
  ax = sns.distplot(kick_data,hist=False,label= kick_type_names[index])
  #title
  ax.set_title('Hang Time Distribution')

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2657: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# /usr/local/lib/python3.9/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2657: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# /usr/local/lib/python3.9/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **kick length vs return length**

# %%
from scipy import stats
# figure
plt.figure(figsize=(10, 6))
# getting data
#kick_length_data = plays["kickLength"]
#kick_return_data = plays["kickReturnYardage"]
# Punt, Field Goal, Punt
kick_type = "Punt"
kick_length_data = plays.loc[(plays["specialTeamsPlayType"] == kick_type), "kickLength"]
kick_return_data = plays.loc[(plays["specialTeamsPlayType"] == kick_type), "kickReturnYardage"]
# plotting
plt.scatter(kick_length_data,kick_return_data,s=2)
#title
plt.title('Kick length vs return length')
plt.xlabel("Kick length")
plt.ylabel("Return yardage")
# showing
plt.show()
